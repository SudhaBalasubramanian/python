# %% [markdown]
# 1. Create 3 variables to store street, city and country, now create address variable to store entire address. Use two ways of creating this variable, one using + operator and the other using f-string. Now Print the address in such a way that the street, city and country prints in a separate line

# %%
street = '1 test street'
city = 'Coventry'
country = 'United Kingdom'
address = street + '\n' + city + '\n' + country
address1 = f'{street} \n {city} \n {country}'
address2 = '{} \n {} \n {}'.format(street, city, country)
print('Print address using string format \n', address2)
print('Print address using f-string \n', address1)
print('Print address using + \n', address)
# Out:
# Print address using string format
#  1 test street
#  Coventry
#  United Kingdom
# Print address using f-string
#  1 test street
#  Coventry
#  United Kingdom
# Print address using +
#  1 test street
# Coventry
# United Kingdom

# %% [markdown]
# 2. Create a variable to store the string "Earth revolves around the sun"
# i. Print "revolves" using slice operator
# ii. Print "sun" using negative index

# %%
text = 'Earth revolves around the sun'
print("print revolves using slice operator - ", text[6:14])
print('print sun using negative index - ', text[-3:])
# Out:
# print revolves using slice operator -  revolves
# print sun using negative index -  sun

# %% [markdown]
# 3. Create two variables to store how many fruits and vegetables you eat in a day. Now Print "I eat x veggies and y fruits daily" where x and y presents vegetables and fruits that you eat everyday. Use python f string for this.

# %%
fruits_count = int(input('How many fruits you eat in a day'))
vegetables_count = int(input('How many vegetables you eat in a day'))
output = f'I eat {vegetables_count} veggies and {fruits_count} fruits daily'
print(output)
# Out:
# I eat 3 veggies and 2 fruits daily

# %% [markdown]
# 4. I have a string variable called s='maine 200 banana khaye'. This of course is a wrong statement, the correct statement is 'maine 10 samosa khaye'. Replace incorrect words in original strong with new ones and print the new string. Also try to do this in one line.

# %%
s='maine 200 banana khaye'
new_string = s.replace('banana', 'samosa').replace('200', '10')
print(new_string)
# Out:
# maine 10 samosa khaye
